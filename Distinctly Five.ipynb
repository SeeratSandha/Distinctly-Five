# %% [markdown]
# <a href="https://colab.research.google.com/github/SeeratSandha/Distinctly-Five/blob/main/Distinctly%20Five.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find a list of words with five distinct letters :

from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/")  # Change to the directory we put CROSSWD.TXT in
os.listdir()  # And then we can get the contents of that directory
f = open(" CROSSWD.TXT", "r")  # r is for read, w for write
f.readline()
f.close()
f = open(" CROSSWD.TXT", "r")
words = f.readlines()
listing = []
count =0
for i in words:
  i=i[:-1]
  happy = {s for s in i if len(list(s)) == len(s)}
  if(len((happy))==5):
    listing.append(i)
print(listing, end=",")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
# A list of five letter words that use distinct letters :

count = []
for i in words:
  i=i[:-1]
  if(len(i)==5):
    counting = {s for s in i if len(list(s)) == len(s)}
    if(len(counting) == len(i)):
     count.append(i)
print(count, end=",")
# Out:
# ['abets', 'abhor', 'abide', 'abied', 'abies', 'abler', 'ables', 'abmho', 'abode', 'abohm', 'aboil', 'abort', 'about', 'above', 'abris', 'abuse', 'abuts', 'abyed', 'abyes', 'abysm', 'acerb', 'acers', 'ached', 'aches', 'acids', 'acidy', 'acing', 'acmes', 'acned', 'acnes', 'acold', 'acorn', 'acred', 'acres', 'acrid', 'acted', 'actin', 'actor', 'acute', 'acyls', 'adept', 'adieu', 'adios', 'adits', 'admen', 'admit', 'admix', 'adobe', 'adopt', 'adore', 'adorn', 'adown', 'adoze', 'adult', 'adunc', 'adust', 'adzes', 'aegis', 'aeons', 'afire', 'afore', 'afoul', 'afrit', 'after', 'agent', 'agers', 'agile', 'agios', 'agist', 'aglet', 'agley', 'aglow', 'agone', 'agons', 'agony', 'agues', 'ahold', 'ahoys', 'aider', 'aides', 'ailed', 'aimed', 'aimer', 'aired', 'airns', 'airth', 'airts', 'aisle', 'aitch', 'aiver', 'album', 'alder', 'alecs', 'alefs', 'aleph', 'alert', 'algid', 'algin', 'algor', 'algum', 'alien', 'alifs', 'align', 'alike', 'aline', 'alist', 'alive', 'alkyd', 'almeh', 'almes', 'almud'
# ...

# %%
# A list of five letter words that use four vowels :

count =0
vowels = 'aeiouAEIOU'
wording=[]
counting = []
new = ''.join(i)
for i in words:
  i=i[:-1]
  if(len(i)==5):
     count =count +1
     count = sum(1 for char in i if char in vowels)
     if(count==4):
       wording.append(i)
print(wording , end=",")
# Out:
# ['aalii', 'adieu', 'aecia', 'aerie', 'ainee', 'aquae', 'areae', 'audio', 'aurae', 'aurei', 'cooee', 'eerie', 'looie', 'louie', 'miaou', 'oidia', 'oorie', 'ourie', 'queue', 'uraei', 'zoeae'],
